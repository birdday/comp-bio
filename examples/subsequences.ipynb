# %%
from comp_bio.subsequences import calc_score_matrix, calc_value_matrix, print_matrix
import numpy as np

# %%
seq1 = 'TAACCTTTATCTGCCA'
seq2 = 'TAACGGCCCATCTCGA'
score_mat = calc_score_matrix(seq1, seq2)
print_matrix(seq1, seq2, score_mat)
val_mat = calc_value_matrix(seq1, seq2)
print_matrix(seq1, seq2, val_mat)
